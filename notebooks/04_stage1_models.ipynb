# %% [markdown]
# # 04 — Stage 1 models
#
# The primary model is the two-view CNN. The LSTM and compact Transformer use the same fixed samples, partitions, and validation budget. On systems without PyTorch, use the view-classifier fallback only as a sanity baseline.

# %%
from transit_hunter.models import build_two_view_model, train_two_view_cnn

# global_train/local_train/global_validation/local_validation are arrays loaded from frozen NPZ samples.
# model, history = train_two_view_cnn(global_train, local_train, y_train, global_validation, local_validation, y_validation, architecture='cnn')
# For controlled comparisons: architecture='lstm' or architecture='transformer'.
print('Use only frozen train/validation arrays here; save the final checkpoint and history manifest.')
